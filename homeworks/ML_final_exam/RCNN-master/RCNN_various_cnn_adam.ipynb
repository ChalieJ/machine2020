# %%
# !unzip Images.zip

# %%
# !unzip Airplanes_Annotations.zip
# Out:
# 'unzip'은(는) 내부 또는 외부 명령, 실행할 수 있는 프로그램, 또는
# 배치 파일이 아닙니다.

# %%
import os,cv2,keras
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
# Out:
# Using TensorFlow backend.
# d:\apps\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# d:\apps\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# d:\apps\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# d:\apps\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# d:\apps\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# d:\apps\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# d:\apps\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# d:\apps\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# d:\apps\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# d:\apps\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# d:\apps\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# d:\apps\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
path = "Images"
annot = "Airplanes_Annotations"

# %%
# 견본 이미지와 CSV로 어떤 정보가 있는지 확인
for e,i in enumerate(os.listdir(annot)):
    if e < 10:
        filename = i.split(".")[0]+".jpg"
        print(filename)
        img = cv2.imread(os.path.join(path,filename))
        df = pd.read_csv(os.path.join(annot,i))
        
        print("img filename", os.path.join(path,filename))
        print("df filename", os.path.join(annot,i))
        
        # show original image
        plt.imshow(img)

        # data frame 에서 네모 좌표값을 획득하여, 이미지 위에 그려준다
        for row in df.iterrows():
            x1 = int(row[1][0].split(" ")[0])
            y1 = int(row[1][0].split(" ")[1])
            x2 = int(row[1][0].split(" ")[2])
            y2 = int(row[1][0].split(" ")[3])
            cv2.rectangle(img,(x1,y1),(x2,y2),(255,0,0), 2)

        plt.figure()
        plt.imshow(img)
        break
# Out:
# 42845.jpg
# img filename Images\42845.jpg
# df filename Airplanes_Annotations\42845.csv

# %%
# selective search 테스트
# selective search 오브젝트 생성
cv2.setUseOptimized(True);
ss = cv2.ximgproc.segmentation.createSelectiveSearchSegmentation()

# %%
# selective search 사용법 확인
im = cv2.imread(os.path.join(path,"42845.jpg"))

ss.setBaseImage(im)
ss.switchToSelectiveSearchFast()
# 오브젝트 찾기 작업
rects = ss.process()
imOut = im.copy()

for i, rect in (enumerate(rects)):
    # 찾은 오브젝트들 반복하면서 네모를 그려준다
    x, y, w, h = rect
    #print(x,y,w,h)
    #imOut = imOut[x:x+w,y:y+h]
    cv2.rectangle(imOut, (x, y), (x + w, y + h), (0, 255, 0), 1, cv2.LINE_AA)
# plt.figure()

plt.imshow(imOut)

# %%
# test code
# selective search로 찾아낸 네모중에 1개를 그려본다.

imOut1 = im.copy()

rrr = rects[14]
x1, y1, w1, h1 = rrr
cv2.rectangle(imOut1, (x1, y1), (x1 + w1, y1 + h1), (0, 255, 0), 1, cv2.LINE_AA)
plt.imshow(imOut1)

# %%
train_images=[]
train_labels=[]

# %%
# iou 중첩도 계산 (데이터 셋과 비교하여, 비행기 인지 찾기)
# https://www.pyimagesearch.com/2016/11/07/intersection-over-union-iou-for-object-detection/

def get_iou(bb1, bb2):
    assert bb1['x1'] < bb1['x2']
    assert bb1['y1'] < bb1['y2']
    assert bb2['x1'] < bb2['x2']
    assert bb2['y1'] < bb2['y2']

    # get Minimum size box
    x_left = max(bb1['x1'], bb2['x1'])
    y_top = max(bb1['y1'], bb2['y1'])
    x_right = min(bb1['x2'], bb2['x2'])
    y_bottom = min(bb1['y2'], bb2['y2'])

    if x_right < x_left or y_bottom < y_top:
        return 0.0

    intersection_area = (x_right - x_left) * (y_bottom - y_top)

    bb1_area = (bb1['x2'] - bb1['x1']) * (bb1['y2'] - bb1['y1'])
    bb2_area = (bb2['x2'] - bb2['x1']) * (bb2['y2'] - bb2['y1'])

    iou = intersection_area / float(bb1_area + bb2_area - intersection_area)
    assert iou >= 0.0
    assert iou <= 1.0
    return iou

# %%
ss = cv2.ximgproc.segmentation.createSelectiveSearchSegmentation()

# %%
for e,i in enumerate(os.listdir(annot)):
    try:
        if i.startswith("airplane"):
            # load dataset
            filename = i.split(".")[0]+".jpg"
            print(e,filename)
            image = cv2.imread(os.path.join(path,filename))
            df = pd.read_csv(os.path.join(annot,i))
            gtvalues=[]

            # get airplain location
            for row in df.iterrows():
                x1 = int(row[1][0].split(" ")[0])
                y1 = int(row[1][0].split(" ")[1])
                x2 = int(row[1][0].split(" ")[2])
                y2 = int(row[1][0].split(" ")[3])
                gtvalues.append({"x1":x1,"x2":x2,"y1":y1,"y2":y2})

            #print(gtvalues) # airplain location value
                
            # selective search process
            ss.setBaseImage(image)
            ss.switchToSelectiveSearchFast()
            ssresults = ss.process()
            imout = image.copy()

            counter = 0
            falsecounter = 0
            flag = 0
            fflag = 0
            bflag = 0

            for e,result in enumerate(ssresults):
                # selective search는 2000개 정도의 ragion을 생성함다 (네모)
                if e < 2000 and flag == 0:
                    for gtval in gtvalues:
                        x,y,w,h = result
                        #print(x,y,w,h)
                        
                        # gtvalues : any one in csv data
                        # x, w, y, h : any one in selective search data
                        iou = get_iou(gtval,{"x1":x,"x2":x+w,"y1":y,"y2":y+h})

                        if counter < 30:
                            if iou > 0.70:
                                timage = imout[y:y+h,x:x+w]
                                resized = cv2.resize(timage, (224,224), interpolation = cv2.INTER_AREA)
                                train_images.append(resized)
                                train_labels.append(1)
                                counter += 1
                        else :
                            fflag =1
                        if falsecounter < 30:
                            if iou < 0.3:
                                timage = imout[y:y+h,x:x+w]
                                resized = cv2.resize(timage, (224,224), interpolation = cv2.INTER_AREA)
                                train_images.append(resized)
                                train_labels.append(0)
                                falsecounter += 1
                        else :
                            bflag = 1
                    if fflag == 1 and bflag == 1:
                        print("inside")
                        flag = 1
    except Exception as e:
        print(e)
        print("error in "+filename)

        continue
# Out:
# 17 airplane_001.jpg
# inside
# 18 airplane_002.jpg
# 19 airplane_003.jpg
# 20 airplane_004.jpg
# inside
# 21 airplane_005.jpg
# inside
# 22 airplane_006.jpg
# 23 airplane_007.jpg
# inside
# 24 airplane_008.jpg
# 25 airplane_009.jpg
# 26 airplane_010.jpg
# 27 airplane_011.jpg
# 28 airplane_012.jpg
# inside
# 29 airplane_013.jpg
# 30 airplane_014.jpg
# 31 airplane_015.jpg
# 32 airplane_016.jpg
# 33 airplane_017.jpg
# 34 airplane_018.jpg
# 35 airplane_019.jpg
# 36 airplane_020.jpg
# 37 airplane_021.jpg
# 38 airplane_022.jpg
# 39 airplane_023.jpg
# 40 airplane_024.jpg
# 41 airplane_025.jpg
# 42 airplane_026.jpg
# 43 airplane_027.jpg
# 44 airplane_028.jpg
# 45 airplane_029.jpg
# 46 airplane_030.jpg
# 47 airplane_031.jpg
# 48 airplane_032.jpg
# 49 airplane_033.jpg
# 50 airplane_034.jpg
# 51 airplane_035.jpg
# 52 airplane_036.jpg
# 53 airplane_037.jpg
# 54 airplane_038.jpg
# 55 airplane_039.jpg
# 56 airplane_040.jpg
# 57 airplane_041.jpg
# inside
# 58 airplane_042.jpg
# 59 airplane_043.jpg
# 60 airplane_044.jpg
# 61 airplane_045.jpg
# inside
# 62 airplane_046.jpg
# 63 airplane_047.jpg
# %%
# 구분해낸 데이터에서 labels갑과 image가 일치하는지 확인
# labels 값이 1이면 이미지가 비행기이다!

X_new = np.array(train_images)
y_new = np.array(train_labels)

for i,iter in enumerate(train_images):
    if train_labels[i] == 1:    # 라벨값이 참이면
        plt.imshow(iter)        # 이미지 확인
        break

# %%
print("total train : ", y_new.size)
print("true train : ", (y_new == 1).sum())
print("false train : ", (y_new == 0).sum())


print((y_new == 0).sum() / y_new.size)
print((y_new == 1).sum() / y_new.size)
# Out:
# total train :  30229
# true train :  9289
# false train :  20940
# 0.6927122961394687
# 0.3072877038605313

# %%
# 데이터의 shape 확인
print(X_new.shape)
print(y_new.shape)
# Out:
# (30229, 224, 224, 3)
# (30229,)

# %%
from keras.layers import Dense
from keras import Model
from keras import optimizers
from keras.preprocessing.image import ImageDataGenerator
from keras.applications.vgg16 import VGG16

from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D

# %%
# 모델 만들기 1 - 평범한 CNN 모델
model = Sequential()
model.add(Conv2D(64, (3, 3), padding='same', input_shape=X_new.shape[1:]))
model.add(Activation('relu'))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Conv2D(128, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(128, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(2))
model.add(Activation('softmax'))
model.summary()
# Out:
# WARNING:tensorflow:From d:\apps\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 224, 224, 64)      1792
# _________________________________________________________________
# activation_1 (Activation)    (None, 224, 224, 64)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 222, 222, 64)      36928
# _________________________________________________________________
# activation_2 (Activation)    (None, 222, 222, 64)      0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 111, 111, 64)      0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 111, 111, 64)      0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 111, 111, 128)     73856
# _________________________________________________________________
# activation_3 (Activation)    (None, 111, 111, 128)     0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 109, 109, 128)     147584
# _________________________________________________________________
# activation_4 (Activation)    (None, 109, 109, 128)     0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 54, 54, 128)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 54, 54, 128)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 373248)            0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               191103488
# _________________________________________________________________
# activation_5 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 1026
# _________________________________________________________________
# activation_6 (Activation)    (None, 2)                 0
# =================================================================
# Total params: 191,364,674
# Trainable params: 191,364,674
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 모델 만들기 2 - VGG 모델 밴치마킹 에서 2개정도 삭제
#
# model = Sequential()
# model.add(Conv2D(64, (3, 3), padding='same', input_shape=X_new.shape[1:]))
# model.add(Activation('relu'))
# model.add(Conv2D(64, (3, 3), padding='same'))
# model.add(Activation('relu'))
#
# model.add(MaxPooling2D(pool_size=(2, 2)))
# model.add(Dropout(0.25))
#
# model.add(Conv2D(128, (3, 3), padding='same'))
# model.add(Activation('relu'))
# model.add(Conv2D(128, (3, 3), padding='same'))
# model.add(Activation('relu'))
#
# model.add(MaxPooling2D(pool_size=(2, 2)))
# model.add(Dropout(0.25))
#
# model.add(Conv2D(256, (3, 3), padding='same'))
# model.add(Activation('relu'))
# model.add(Conv2D(256, (3, 3), padding='same'))
# model.add(Activation('relu'))
# #model.add(Conv2D(256, (3, 3), padding='same'))
# #model.add(Activation('relu'))
#
# model.add(MaxPooling2D(pool_size=(2, 2)))
# model.add(Dropout(0.25))
#
# model.add(Conv2D(512, (3, 3), padding='same'))
# model.add(Activation('relu'))
# model.add(Conv2D(512, (3, 3), padding='same'))
# model.add(Activation('relu'))
# #model.add(Conv2D(512, (3, 3), padding='same'))
# #model.add(Activation('relu'))
#
# model.add(MaxPooling2D(pool_size=(2, 2)))
# model.add(Dropout(0.25))
#
# model.add(Flatten())
# model.add(Dense(512))
# model.add(Activation('relu'))
# model.add(Dropout(0.5))
# model.add(Dense(2))
# model.add(Activation('softmax'))
# model.summary()

# %% [markdown]
# # 모델 만들기 3 - VGG 모델 밴치마킹
#
# model = Sequential()
# model.add(Conv2D(64, (3, 3), padding='same', input_shape=X_new.shape[1:]))
# model.add(Activation('relu'))
# model.add(Conv2D(64, (3, 3), padding='same'))
# model.add(Activation('relu'))
#
# model.add(MaxPooling2D(pool_size=(2, 2)))
# model.add(Dropout(0.25))
#
# model.add(Conv2D(128, (3, 3), padding='same'))
# model.add(Activation('relu'))
# model.add(Conv2D(128, (3, 3), padding='same'))
# model.add(Activation('relu'))
#
# model.add(MaxPooling2D(pool_size=(2, 2)))
# model.add(Dropout(0.25))
#
# model.add(Conv2D(256, (3, 3), padding='same'))
# model.add(Activation('relu'))
# model.add(Conv2D(256, (3, 3), padding='same'))
# model.add(Activation('relu'))
# model.add(Conv2D(256, (3, 3), padding='same'))
# model.add(Activation('relu'))
#
# model.add(MaxPooling2D(pool_size=(2, 2)))
# model.add(Dropout(0.25))
#
# model.add(Conv2D(512, (3, 3), padding='same'))
# model.add(Activation('relu'))
# model.add(Conv2D(512, (3, 3), padding='same'))
# model.add(Activation('relu'))
# model.add(Conv2D(512, (3, 3), padding='same'))
# model.add(Activation('relu'))
#
# model.add(MaxPooling2D(pool_size=(2, 2)))
# model.add(Dropout(0.25))
#
# model.add(Flatten())
# model.add(Dense(512))
# model.add(Activation('relu'))
# model.add(Dropout(0.5))
# model.add(Dense(2))
# model.add(Activation('softmax'))
# model.summary()

# %%
for layers in (model.layers)[:15]:
    print(layers)
    layers.trainable = False
# Out:
# <keras.layers.convolutional.Conv2D object at 0x0000019B79CFAFC8>
# <keras.layers.core.Activation object at 0x0000019B79CC7888>
# <keras.layers.convolutional.Conv2D object at 0x0000019B79D2BE88>
# <keras.layers.core.Activation object at 0x0000019B79D3EEC8>
# <keras.layers.pooling.MaxPooling2D object at 0x0000019B79D52988>
# <keras.layers.core.Dropout object at 0x0000019B79D63AC8>
# <keras.layers.convolutional.Conv2D object at 0x0000019B79D7CD48>
# <keras.layers.core.Activation object at 0x0000019B79D63A88>
# <keras.layers.convolutional.Conv2D object at 0x0000019B79D1EEC8>
# <keras.layers.core.Activation object at 0x0000019B79DFCD08>
# <keras.layers.pooling.MaxPooling2D object at 0x0000019B091D02C8>
# <keras.layers.core.Dropout object at 0x0000019B79E1C6C8>
# <keras.layers.core.Flatten object at 0x0000019B79E1C748>
# <keras.layers.core.Dense object at 0x0000019B79E39608>
# <keras.layers.core.Activation object at 0x0000019B79E39C08>

# %%
X= model.layers[-2].output

# %%
from keras.optimizers import Adam
opt = keras.optimizers.RMSprop(learning_rate=0.0001, decay=1e-6)

# %%
#model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# 모델 구성 확인
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 224, 224, 64)      1792
# _________________________________________________________________
# activation_1 (Activation)    (None, 224, 224, 64)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 222, 222, 64)      36928
# _________________________________________________________________
# activation_2 (Activation)    (None, 222, 222, 64)      0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 111, 111, 64)      0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 111, 111, 64)      0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 111, 111, 128)     73856
# _________________________________________________________________
# activation_3 (Activation)    (None, 111, 111, 128)     0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 109, 109, 128)     147584
# _________________________________________________________________
# activation_4 (Activation)    (None, 109, 109, 128)     0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 54, 54, 128)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 54, 54, 128)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 373248)            0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               191103488
# _________________________________________________________________
# activation_5 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 1026
# _________________________________________________________________
# activation_6 (Activation)    (None, 2)                 0
# =================================================================
# Total params: 191,364,674
# Trainable params: 1,026
# Non-trainable params: 191,363,648
# _________________________________________________________________

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer

# %%
class MyLabelBinarizer(LabelBinarizer):
    def transform(self, y):
        Y = super().transform(y)
        if self.y_type_ == 'binary':
            return np.hstack((Y, 1-Y))
        else:
            return Y
    def inverse_transform(self, Y, threshold=None):
        if self.y_type_ == 'binary':
            return super().inverse_transform(Y[:, 0], threshold)
        else:
            return super().inverse_transform(Y, threshold)

# %%
# 값을 binary화 시킴
lenc = MyLabelBinarizer()
Y =  lenc.fit_transform(y_new)

# %%
# train set과 test set으로 구분
X_train, X_test , y_train, y_test = train_test_split(X_new,Y,test_size=0.10)

# %%
print(X_train.shape,X_test.shape,y_train.shape,y_test.shape)
# Out:
# (27206, 224, 224, 3) (3023, 224, 224, 3) (27206, 2) (3023, 2)

# %%
trdata = ImageDataGenerator(horizontal_flip=True, vertical_flip=True, rotation_range=90)
traindata = trdata.flow(x=X_train, y=y_train)
#, batch_size=1
tsdata = ImageDataGenerator(horizontal_flip=True, vertical_flip=True, rotation_range=90)
testdata = tsdata.flow(x=X_test, y=y_test)

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
checkpoint = ModelCheckpoint("various_cnn_models.h5", monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)
early = EarlyStopping(monitor='val_loss', min_delta=0, patience=100, verbose=1, mode='auto')

# %%
hist = model.fit_generator(generator= traindata, steps_per_epoch= 10, epochs= 1000, workers=1, validation_data= testdata, validation_steps=2, callbacks=[checkpoint,early])

#max_queue_size=256,
# Out:
# WARNING:tensorflow:From d:\apps\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Epoch 1/1000
# 10/10 [==============================] - 11s 1s/step - loss: 10.6406 - accuracy: 0.5875 - val_loss: 1.4071 - val_accuracy: 0.5781
#
# Epoch 00001: val_loss improved from inf to 1.40714, saving model to various_cnn_models.h5
# Epoch 2/1000
# 10/10 [==============================] - 1s 101ms/step - loss: 11.6293 - accuracy: 0.5813 - val_loss: 1.3534 - val_accuracy: 0.6406
#
# Epoch 00002: val_loss improved from 1.40714 to 1.35338, saving model to various_cnn_models.h5
# Epoch 3/1000
# 10/10 [==============================] - 3s 286ms/step - loss: 9.3931 - accuracy: 0.5500 - val_loss: 1.3453 - val_accuracy: 0.6719
#
# Epoch 00003: val_loss improved from 1.35338 to 1.34532, saving model to various_cnn_models.h5
# Epoch 4/1000
# 10/10 [==============================] - 3s 290ms/step - loss: 9.6642 - accuracy: 0.5562 - val_loss: 3.3469 - val_accuracy: 0.6250
#
# Epoch 00004: val_loss did not improve from 1.34532
# Epoch 5/1000
# 10/10 [==============================] - 3s 302ms/step - loss: 11.3978 - accuracy: 0.5531 - val_loss: 2.3581 - val_accuracy: 0.6406
#
# Epoch 00005: val_loss did not improve from 1.34532
# Epoch 6/1000
# 10/10 [==============================] - 3s 298ms/step - loss: 10.2332 - accuracy: 0.5406 - val_loss: 1.8578 - val_accuracy: 0.7344
#
# Epoch 00006: val_loss did not improve from 1.34532
# Epoch 7/1000
# 10/10 [==============================] - 3s 290ms/step - loss: 10.0816 - accuracy: 0.6000 - val_loss: 2.5249 - val_accuracy: 0.6719
#
# Epoch 00007: val_loss did not improve from 1.34532
# Epoch 8/1000
# 10/10 [==============================] - 3s 295ms/step - loss: 10.5097 - accuracy: 0.5625 - val_loss: 1.3974 - val_accuracy: 0.6094
#
# Epoch 00008: val_loss did not improve from 1.34532
# Epoch 9/1000
# 10/10 [==============================] - 4s 350ms/step - loss: 8.1923 - accuracy: 0.5625 - val_loss: 1.7536 - val_accuracy: 0.6562
#
# Epoch 00009: val_loss did not improve from 1.34532
# Epoch 10/1000
# 10/10 [==============================] - 3s 293ms/step - loss: 7.0558 - accuracy: 0.6031 - val_loss: 0.9954 - val_accuracy: 0.6406
#
# Epoch 00010: val_loss improved from 1.34532 to 0.99537, saving model to various_cnn_models.h5
# Epoch 11/1000
# 10/10 [==============================] - 3s 282ms/step - loss: 7.2538 - accuracy: 0.5719 - val_loss: 1.8994 - val_accuracy: 0.6875
#
# Epoch 00011: val_loss did not improve from 0.99537
# Epoch 12/1000
# 10/10 [==============================] - 3s 298ms/step - loss: 6.9354 - accuracy: 0.6250 - val_loss: 2.7348 - val_accuracy: 0.6562
#
# Epoch 00012: val_loss did not improve from 0.99537
# Epoch 13/1000
# 10/10 [==============================] - 3s 308ms/step - loss: 7.8071 - accuracy: 0.5469 - val_loss: 0.5270 - val_accuracy: 0.8125
#
# Epoch 00013: val_loss improved from 0.99537 to 0.52696, saving model to various_cnn_models.h5
# Epoch 14/1000
# 10/10 [==============================] - 3s 294ms/step - loss: 6.7448 - accuracy: 0.6500 - val_loss: 1.9151 - val_accuracy: 0.6719
#
# Epoch 00014: val_loss did not improve from 0.52696
# Epoch 15/1000
# 10/10 [==============================] - 3s 305ms/step - loss: 7.0798 - accuracy: 0.5531 - val_loss: 0.7998 - val_accuracy: 0.6719
#
# Epoch 00015: val_loss did not improve from 0.52696
# Epoch 16/1000
# 10/10 [==============================] - 4s 387ms/step - loss: 6.1365 - accuracy: 0.6062 - val_loss: 2.2751 - val_accuracy: 0.6562
#
# Epoch 00016: val_loss did not improve from 0.52696
# Epoch 17/1000
# 10/10 [==============================] - 3s 310ms/step - loss: 6.4648 - accuracy: 0.6187 - val_loss: 0.8468 - val_accuracy: 0.7344
#
# Epoch 00017: val_loss did not improve from 0.52696
# Epoch 18/1000
# 10/10 [==============================] - 3s 299ms/step - loss: 5.4998 - accuracy: 0.5750 - val_loss: 2.7643 - val_accuracy: 0.6406
#
# Epoch 00018: val_loss did not improve from 0.52696
# Epoch 19/1000
# 10/10 [==============================] - 3s 292ms/step - loss: 5.4769 - accuracy: 0.6156 - val_loss: 1.4238 - val_accuracy: 0.7500
#
# Epoch 00019: val_loss did not improve from 0.52696
# Epoch 20/1000
# 10/10 [==============================] - 3s 296ms/step - loss: 5.8137 - accuracy: 0.5312 - val_loss: 0.4502 - val_accuracy: 0.7656
#
# Epoch 00020: val_loss improved from 0.52696 to 0.45017, saving model to various_cnn_models.h5
# Epoch 21/1000
# 10/10 [==============================] - 3s 316ms/step - loss: 5.7217 - accuracy: 0.6062 - val_loss: 1.0019 - val_accuracy: 0.7656
#
# Epoch 00021: val_loss did not improve from 0.45017
# Epoch 22/1000
# 10/10 [==============================] - 3s 301ms/step - loss: 4.1936 - accuracy: 0.6250 - val_loss: 0.6187 - val_accuracy: 0.7656
#
# Epoch 00022: val_loss did not improve from 0.45017
# Epoch 23/1000
# 10/10 [==============================] - 4s 433ms/step - loss: 4.1898 - accuracy: 0.6031 - val_loss: 1.4432 - val_accuracy: 0.6562
#
# Epoch 00023: val_loss did not improve from 0.45017
# Epoch 24/1000
# 10/10 [==============================] - 3s 322ms/step - loss: 4.3003 - accuracy: 0.6094 - val_loss: 1.0505 - val_accuracy: 0.8125
#
# Epoch 00024: val_loss did not improve from 0.45017
# Epoch 25/1000
# 10/10 [==============================] - 3s 299ms/step - loss: 3.8974 - accuracy: 0.5938 - val_loss: 0.6366 - val_accuracy: 0.7969
#
# Epoch 00025: val_loss did not improve from 0.45017
# Epoch 26/1000
# 10/10 [==============================] - 3s 302ms/step - loss: 3.8043 - accuracy: 0.6313 - val_loss: 1.2908 - val_accuracy: 0.7031
#
# Epoch 00026: val_loss did not improve from 0.45017
# Epoch 27/1000
# 10/10 [==============================] - 3s 299ms/step - loss: 3.7691 - accuracy: 0.6000 - val_loss: 0.9449 - val_accuracy: 0.7656
#
# Epoch 00027: val_loss did not improve from 0.45017
# Epoch 28/1000
# 10/10 [==============================] - 3s 310ms/step - loss: 3.1439 - accuracy: 0.6125 - val_loss: 0.7284 - val_accuracy: 0.7812
#
# Epoch 00028: val_loss did not improve from 0.45017
# Epoch 29/1000
# 10/10 [==============================] - 3s 306ms/step - loss: 2.9183 - accuracy: 0.6281 - val_loss: 0.8493 - val_accuracy: 0.7344
#
# Epoch 00029: val_loss did not improve from 0.45017
# Epoch 30/1000
# 10/10 [==============================] - 4s 350ms/step - loss: 2.8378 - accuracy: 0.6313 - val_loss: 1.0776 - val_accuracy: 0.7500
#
# Epoch 00030: val_loss did not improve from 0.45017
# Epoch 31/1000
# 10/10 [==============================] - 3s 310ms/step - loss: 3.0496 - accuracy: 0.6062 - val_loss: 0.4926 - val_accuracy: 0.8281
#
# Epoch 00031: val_loss did not improve from 0.45017
# Epoch 32/1000
# 10/10 [==============================] - 3s 340ms/step - loss: 2.2526 - accuracy: 0.6844 - val_loss: 0.4941 - val_accuracy: 0.7969
#
# Epoch 00032: val_loss did not improve from 0.45017
# Epoch 33/1000
# 10/10 [==============================] - 3s 298ms/step - loss: 2.8398 - accuracy: 0.5813 - val_loss: 1.5458 - val_accuracy: 0.6875
#
# Epoch 00033: val_loss did not improve from 0.45017
# Epoch 34/1000
# 10/10 [==============================] - 3s 314ms/step - loss: 2.8951 - accuracy: 0.6187 - val_loss: 0.4476 - val_accuracy: 0.6406
#
# Epoch 00034: val_loss improved from 0.45017 to 0.44756, saving model to various_cnn_models.h5
# Epoch 35/1000
# 10/10 [==============================] - 3s 291ms/step - loss: 2.4963 - accuracy: 0.5813 - val_loss: 0.4207 - val_accuracy: 0.7344
#
# Epoch 00035: val_loss improved from 0.44756 to 0.42074, saving model to various_cnn_models.h5
# Epoch 36/1000
# 10/10 [==============================] - 4s 352ms/step - loss: 2.2673 - accuracy: 0.6000 - val_loss: 0.6154 - val_accuracy: 0.7031
#
# Epoch 00036: val_loss did not improve from 0.42074
# Epoch 37/1000
# 10/10 [==============================] - 4s 373ms/step - loss: 1.9465 - accuracy: 0.6687 - val_loss: 0.3691 - val_accuracy: 0.6875
#
# Epoch 00037: val_loss improved from 0.42074 to 0.36910, saving model to various_cnn_models.h5
# Epoch 38/1000
# 10/10 [==============================] - 4s 354ms/step - loss: 2.2521 - accuracy: 0.6344 - val_loss: 0.6486 - val_accuracy: 0.7188
#
# Epoch 00038: val_loss did not improve from 0.36910
# Epoch 39/1000
# 10/10 [==============================] - 4s 433ms/step - loss: 1.8317 - accuracy: 0.6750 - val_loss: 0.7236 - val_accuracy: 0.8438
# Epoch 00039: val_loss did not improve from 0.36910
# Epoch 40/1000
# 10/10 [==============================] - 3s 321ms/step - loss: 1.8416 - accuracy: 0.6531 - val_loss: 0.5493 - val_accuracy: 0.7500
#
# Epoch 00040: val_loss did not improve from 0.36910
# Epoch 41/1000
# 10/10 [==============================] - 3s 315ms/step - loss: 1.9758 - accuracy: 0.5844 - val_loss: 0.7203 - val_accuracy: 0.7344
#
# Epoch 00041: val_loss did not improve from 0.36910
# Epoch 42/1000
# 10/10 [==============================] - 3s 314ms/step - loss: 1.5172 - accuracy: 0.6094 - val_loss: 0.5533 - val_accuracy: 0.8125
#
# Epoch 00042: val_loss did not improve from 0.36910
# Epoch 43/1000
# 10/10 [==============================] - 3s 350ms/step - loss: 1.7090 - accuracy: 0.6187 - val_loss: 0.5519 - val_accuracy: 0.7656
#
# Epoch 00043: val_loss did not improve from 0.36910
# Epoch 44/1000
# 10/10 [==============================] - 3s 313ms/step - loss: 1.8466 - accuracy: 0.5813 - val_loss: 0.5046 - val_accuracy: 0.7500
#
# Epoch 00044: val_loss did not improve from 0.36910
# Epoch 45/1000
# 10/10 [==============================] - 3s 315ms/step - loss: 1.3490 - accuracy: 0.6313 - val_loss: 0.9524 - val_accuracy: 0.7344
#
# Epoch 00045: val_loss did not improve from 0.36910
# Epoch 46/1000
# 10/10 [==============================] - 3s 320ms/step - loss: 1.4535 - accuracy: 0.5875 - val_loss: 0.5660 - val_accuracy: 0.7812
#
# Epoch 00046: val_loss did not improve from 0.36910
# Epoch 47/1000
# 10/10 [==============================] - 3s 321ms/step - loss: 1.4521 - accuracy: 0.6281 - val_loss: 0.6887 - val_accuracy: 0.7188
#
# Epoch 00047: val_loss did not improve from 0.36910
# Epoch 48/1000
# 10/10 [==============================] - 5s 495ms/step - loss: 1.1605 - accuracy: 0.6469 - val_loss: 0.4350 - val_accuracy: 0.8511
#
# Epoch 00048: val_loss did not improve from 0.36910
# Epoch 49/1000
# 10/10 [==============================] - 3s 264ms/step - loss: 1.2768 - accuracy: 0.6031 - val_loss: 0.5384 - val_accuracy: 0.8281
#
# Epoch 00049: val_loss did not improve from 0.36910
# Epoch 50/1000
# 10/10 [==============================] - 3s 320ms/step - loss: 1.3022 - accuracy: 0.6062 - val_loss: 0.6569 - val_accuracy: 0.6875
#
# Epoch 00050: val_loss did not improve from 0.36910
# Epoch 51/1000
# 10/10 [==============================] - 3s 317ms/step - loss: 1.0960 - accuracy: 0.6844 - val_loss: 0.6066 - val_accuracy: 0.6719
#
# Epoch 00051: val_loss did not improve from 0.36910
# Epoch 52/1000
# 10/10 [==============================] - 3s 324ms/step - loss: 1.2470 - accuracy: 0.6531 - val_loss: 0.4989 - val_accuracy: 0.7812
#
# Epoch 00052: val_loss did not improve from 0.36910
# Epoch 53/1000
# 10/10 [==============================] - 4s 371ms/step - loss: 1.3265 - accuracy: 0.6224 - val_loss: 0.9834 - val_accuracy: 0.6719
#
# Epoch 00053: val_loss did not improve from 0.36910
# Epoch 54/1000
# 10/10 [==============================] - 3s 279ms/step - loss: 1.2709 - accuracy: 0.6313 - val_loss: 0.5059 - val_accuracy: 0.7344
#
# Epoch 00054: val_loss did not improve from 0.36910
# Epoch 55/1000
# 10/10 [==============================] - 4s 352ms/step - loss: 1.1242 - accuracy: 0.5969 - val_loss: 0.7822 - val_accuracy: 0.7031
#
# Epoch 00055: val_loss did not improve from 0.36910
# Epoch 56/1000
# 10/10 [==============================] - 3s 337ms/step - loss: 1.5215 - accuracy: 0.5719 - val_loss: 0.8762 - val_accuracy: 0.6406
#
# Epoch 00056: val_loss did not improve from 0.36910
# Epoch 57/1000
# 10/10 [==============================] - 3s 327ms/step - loss: 1.2733 - accuracy: 0.5875 - val_loss: 0.5220 - val_accuracy: 0.7344
#
# Epoch 00057: val_loss did not improve from 0.36910
# Epoch 58/1000
# 10/10 [==============================] - 3s 333ms/step - loss: 1.1537 - accuracy: 0.6156 - val_loss: 0.7787 - val_accuracy: 0.6562
#
# Epoch 00058: val_loss did not improve from 0.36910
# Epoch 59/1000
# 10/10 [==============================] - 4s 430ms/step - loss: 1.0872 - accuracy: 0.6344 - val_loss: 0.6209 - val_accuracy: 0.7344
#
# Epoch 00059: val_loss did not improve from 0.36910
# Epoch 60/1000
# 10/10 [==============================] - 3s 320ms/step - loss: 1.0018 - accuracy: 0.6625 - val_loss: 0.5364 - val_accuracy: 0.7344
#
# Epoch 00060: val_loss did not improve from 0.36910
# Epoch 61/1000
# 10/10 [==============================] - 3s 317ms/step - loss: 0.9829 - accuracy: 0.6562 - val_loss: 0.4638 - val_accuracy: 0.7969
#
# Epoch 00061: val_loss did not improve from 0.36910
# Epoch 62/1000
# 10/10 [==============================] - 3s 337ms/step - loss: 0.9227 - accuracy: 0.6406 - val_loss: 0.6068 - val_accuracy: 0.7188
#
# Epoch 00062: val_loss did not improve from 0.36910
# Epoch 63/1000
# 10/10 [==============================] - 4s 352ms/step - loss: 0.8354 - accuracy: 0.6938 - val_loss: 0.6695 - val_accuracy: 0.7188
#
# Epoch 00063: val_loss did not improve from 0.36910
# Epoch 64/1000
# 10/10 [==============================] - 3s 322ms/step - loss: 0.9017 - accuracy: 0.6656 - val_loss: 0.5314 - val_accuracy: 0.7656
#
# Epoch 00064: val_loss did not improve from 0.36910
# Epoch 65/1000
# 10/10 [==============================] - 3s 346ms/step - loss: 1.0529 - accuracy: 0.6062 - val_loss: 0.6022 - val_accuracy: 0.7656
#
# Epoch 00065: val_loss did not improve from 0.36910
# Epoch 66/1000
# 10/10 [==============================] - 3s 339ms/step - loss: 0.9267 - accuracy: 0.6938 - val_loss: 0.5185 - val_accuracy: 0.7344
#
# Epoch 00066: val_loss did not improve from 0.36910
# Epoch 67/1000
# 10/10 [==============================] - 3s 326ms/step - loss: 0.9498 - accuracy: 0.6750 - val_loss: 0.5512 - val_accuracy: 0.7031
#
# Epoch 00067: val_loss did not improve from 0.36910
# Epoch 68/1000
# 10/10 [==============================] - 4s 407ms/step - loss: 0.9648 - accuracy: 0.6406 - val_loss: 0.4438 - val_accuracy: 0.8438
#
# Epoch 00068: val_loss did not improve from 0.36910
# Epoch 69/1000
# 10/10 [==============================] - 3s 333ms/step - loss: 1.0541 - accuracy: 0.5719 - val_loss: 0.4923 - val_accuracy: 0.7188
#
# Epoch 00069: val_loss did not improve from 0.36910
# Epoch 70/1000
# 10/10 [==============================] - 3s 325ms/step - loss: 1.0235 - accuracy: 0.6313 - val_loss: 0.5950 - val_accuracy: 0.7500
#
# Epoch 00070: val_loss did not improve from 0.36910
# Epoch 71/1000
# 10/10 [==============================] - 3s 344ms/step - loss: 1.2214 - accuracy: 0.6031 - val_loss: 0.4703 - val_accuracy: 0.7031
#
# Epoch 00071: val_loss did not improve from 0.36910
# Epoch 72/1000
# 10/10 [==============================] - 4s 376ms/step - loss: 1.0917 - accuracy: 0.7000 - val_loss: 0.8334 - val_accuracy: 0.5312
#
# Epoch 00072: val_loss did not improve from 0.36910
# Epoch 73/1000
# 10/10 [==============================] - 3s 325ms/step - loss: 1.2240 - accuracy: 0.6094 - val_loss: 0.5597 - val_accuracy: 0.7656
#
# Epoch 00073: val_loss did not improve from 0.36910
# Epoch 74/1000
# 10/10 [==============================] - 4s 357ms/step - loss: 1.1203 - accuracy: 0.6062 - val_loss: 0.5511 - val_accuracy: 0.7656
#
# Epoch 00074: val_loss did not improve from 0.36910
# Epoch 75/1000
# 10/10 [==============================] - 4s 405ms/step - loss: 0.8866 - accuracy: 0.6469 - val_loss: 0.5042 - val_accuracy: 0.7344
#
# Epoch 00075: val_loss did not improve from 0.36910
# Epoch 76/1000
# 10/10 [==============================] - 3s 326ms/step - loss: 0.9606 - accuracy: 0.6031 - val_loss: 0.6035 - val_accuracy: 0.7344
#
# Epoch 00076: val_loss did not improve from 0.36910
# Epoch 77/1000
# 10/10 [==============================] - 3s 326ms/step - loss: 1.0497 - accuracy: 0.6187 - val_loss: 0.7929 - val_accuracy: 0.7031
#
# Epoch 00077: val_loss did not improve from 0.36910
# Epoch 78/1000
# 10/10 [==============================] - 3s 343ms/step - loss: 0.8486 - accuracy: 0.6781 - val_loss: 0.5027 - val_accuracy: 0.7500
#
# Epoch 00078: val_loss did not improve from 0.36910
# Epoch 79/1000
# 10/10 [==============================] - 3s 343ms/step - loss: 0.8629 - accuracy: 0.6469 - val_loss: 0.6292 - val_accuracy: 0.7500
#
# Epoch 00079: val_loss did not improve from 0.36910
# Epoch 80/1000
# 10/10 [==============================] - 3s 343ms/step - loss: 1.0295 - accuracy: 0.6438 - val_loss: 0.6740 - val_accuracy: 0.6875
#
# Epoch 00080: val_loss did not improve from 0.36910
# Epoch 81/1000
# 10/10 [==============================] - 3s 331ms/step - loss: 1.3882 - accuracy: 0.6375 - val_loss: 0.7931 - val_accuracy: 0.5625
#
# Epoch 00081: val_loss did not improve from 0.36910
# Epoch 82/1000
# 10/10 [==============================] - 3s 341ms/step - loss: 1.3343 - accuracy: 0.5938 - val_loss: 0.4971 - val_accuracy: 0.8594
#
# Epoch 00082: val_loss did not improve from 0.36910
# Epoch 83/1000
# 10/10 [==============================] - 3s 337ms/step - loss: 1.0083 - accuracy: 0.6875 - val_loss: 0.7286 - val_accuracy: 0.7031
#
# Epoch 00083: val_loss did not improve from 0.36910
# Epoch 84/1000
# 10/10 [==============================] - 4s 352ms/step - loss: 1.1137 - accuracy: 0.5844 - val_loss: 0.4898 - val_accuracy: 0.8125
#
# Epoch 00084: val_loss did not improve from 0.36910
# Epoch 85/1000
# 10/10 [==============================] - 4s 391ms/step - loss: 1.0266 - accuracy: 0.5969 - val_loss: 0.6571 - val_accuracy: 0.6562
#
# Epoch 00085: val_loss did not improve from 0.36910
# Epoch 86/1000
# 10/10 [==============================] - 3s 323ms/step - loss: 0.9077 - accuracy: 0.6803 - val_loss: 0.5322 - val_accuracy: 0.7656
#
# Epoch 00086: val_loss did not improve from 0.36910
# Epoch 87/1000
# 10/10 [==============================] - 3s 276ms/step - loss: 0.9001 - accuracy: 0.6906 - val_loss: 0.5437 - val_accuracy: 0.7500
#
# Epoch 00087: val_loss did not improve from 0.36910
# Epoch 88/1000
# 10/10 [==============================] - 3s 275ms/step - loss: 1.0854 - accuracy: 0.5875 - val_loss: 0.6601 - val_accuracy: 0.7188
#
# Epoch 00088: val_loss did not improve from 0.36910
# Epoch 89/1000
# 10/10 [==============================] - 3s 276ms/step - loss: 1.0322 - accuracy: 0.6656 - val_loss: 0.8193 - val_accuracy: 0.7188
#
# Epoch 00089: val_loss did not improve from 0.36910
# Epoch 90/1000
# 10/10 [==============================] - 3s 304ms/step - loss: 1.1981 - accuracy: 0.6031 - val_loss: 0.8501 - val_accuracy: 0.7031
#
# Epoch 00090: val_loss did not improve from 0.36910
# Epoch 91/1000
# 10/10 [==============================] - 3s 267ms/step - loss: 1.0617 - accuracy: 0.6313 - val_loss: 0.9506 - val_accuracy: 0.6406
#
# Epoch 00091: val_loss did not improve from 0.36910
# Epoch 92/1000
# 10/10 [==============================] - 3s 265ms/step - loss: 0.8886 - accuracy: 0.6406 - val_loss: 0.6552 - val_accuracy: 0.7656
#
# Epoch 00092: val_loss did not improve from 0.36910
# Epoch 93/1000
# 10/10 [==============================] - 3s 272ms/step - loss: 0.9844 - accuracy: 0.6281 - val_loss: 0.5794 - val_accuracy: 0.7500
#
# Epoch 00093: val_loss did not improve from 0.36910
# Epoch 94/1000
# 10/10 [==============================] - 3s 276ms/step - loss: 1.0813 - accuracy: 0.6156 - val_loss: 0.5519 - val_accuracy: 0.8438
#
# Epoch 00094: val_loss did not improve from 0.36910
# Epoch 95/1000
# 10/10 [==============================] - 3s 284ms/step - loss: 0.9664 - accuracy: 0.6656 - val_loss: 0.6268 - val_accuracy: 0.7447
#
# Epoch 00095: val_loss did not improve from 0.36910
# Epoch 96/1000
# 10/10 [==============================] - 3s 307ms/step - loss: 1.0496 - accuracy: 0.6000 - val_loss: 0.5706 - val_accuracy: 0.6562
#
# Epoch 00096: val_loss did not improve from 0.36910
# Epoch 97/1000
# 10/10 [==============================] - 3s 283ms/step - loss: 0.9359 - accuracy: 0.6969 - val_loss: 0.4902 - val_accuracy: 0.7812
#
# Epoch 00097: val_loss did not improve from 0.36910
# Epoch 98/1000
# 10/10 [==============================] - 3s 282ms/step - loss: 0.9843 - accuracy: 0.6187 - val_loss: 0.4514 - val_accuracy: 0.8125
#
# Epoch 00098: val_loss did not improve from 0.36910
# Epoch 99/1000
# 10/10 [==============================] - 3s 277ms/step - loss: 0.9287 - accuracy: 0.6469 - val_loss: 0.4359 - val_accuracy: 0.7969
#
# Epoch 00099: val_loss did not improve from 0.36910
# Epoch 100/1000
# 10/10 [==============================] - 3s 282ms/step - loss: 0.9744 - accuracy: 0.6062 - val_loss: 0.4694 - val_accuracy: 0.8125
#
# Epoch 00100: val_loss did not improve from 0.36910
# Epoch 101/1000
# 10/10 [==============================] - 3s 286ms/step - loss: 0.9093 - accuracy: 0.6250 - val_loss: 0.4902 - val_accuracy: 0.7812
#
# Epoch 00101: val_loss did not improve from 0.36910
# Epoch 102/1000
# 10/10 [==============================] - 3s 287ms/step - loss: 1.2188 - accuracy: 0.5437 - val_loss: 0.7786 - val_accuracy: 0.6406
#
# Epoch 00102: val_loss did not improve from 0.36910
# Epoch 103/1000
# 10/10 [==============================] - 3s 305ms/step - loss: 0.7990 - accuracy: 0.6500 - val_loss: 0.7308 - val_accuracy: 0.6406
#
# Epoch 00103: val_loss did not improve from 0.36910
# Epoch 104/1000
# 10/10 [==============================] - 3s 308ms/step - loss: 0.9926 - accuracy: 0.6156 - val_loss: 0.4888 - val_accuracy: 0.7656
#
# Epoch 00104: val_loss did not improve from 0.36910
# Epoch 105/1000
# 10/10 [==============================] - 3s 297ms/step - loss: 0.9593 - accuracy: 0.6250 - val_loss: 0.6848 - val_accuracy: 0.6562
#
# Epoch 00105: val_loss did not improve from 0.36910
# Epoch 106/1000
# 10/10 [==============================] - 3s 283ms/step - loss: 0.9468 - accuracy: 0.6469 - val_loss: 0.5530 - val_accuracy: 0.7344
#
# Epoch 00106: val_loss did not improve from 0.36910
# Epoch 107/1000
# 10/10 [==============================] - 3s 292ms/step - loss: 0.9040 - accuracy: 0.6531 - val_loss: 0.3981 - val_accuracy: 0.9219
#
# Epoch 00107: val_loss did not improve from 0.36910
# Epoch 108/1000
# 10/10 [==============================] - 3s 343ms/step - loss: 0.8958 - accuracy: 0.6406 - val_loss: 0.5326 - val_accuracy: 0.7656
#
# Epoch 00108: val_loss did not improve from 0.36910
# Epoch 109/1000
# 10/10 [==============================] - 3s 284ms/step - loss: 0.9394 - accuracy: 0.6313 - val_loss: 0.6098 - val_accuracy: 0.7344
#
# Epoch 00109: val_loss did not improve from 0.36910
# Epoch 110/1000
# 10/10 [==============================] - 3s 283ms/step - loss: 1.0402 - accuracy: 0.6156 - val_loss: 0.5077 - val_accuracy: 0.7812
#
# Epoch 00110: val_loss did not improve from 0.36910
# Epoch 111/1000
# 10/10 [==============================] - 3s 284ms/step - loss: 1.0920 - accuracy: 0.6469 - val_loss: 0.5587 - val_accuracy: 0.7500
#
# Epoch 00111: val_loss did not improve from 0.36910
# Epoch 112/1000
# 10/10 [==============================] - 3s 316ms/step - loss: 1.1601 - accuracy: 0.5969 - val_loss: 0.6054 - val_accuracy: 0.7188
#
# Epoch 00112: val_loss did not improve from 0.36910
# Epoch 113/1000
# 10/10 [==============================] - 3s 292ms/step - loss: 1.0550 - accuracy: 0.6594 - val_loss: 0.5630 - val_accuracy: 0.7344
#
# Epoch 00113: val_loss did not improve from 0.36910
# Epoch 114/1000
# 10/10 [==============================] - 3s 289ms/step - loss: 1.0041 - accuracy: 0.5688 - val_loss: 0.5624 - val_accuracy: 0.7031
#
# Epoch 00114: val_loss did not improve from 0.36910
# Epoch 115/1000
# 10/10 [==============================] - 3s 293ms/step - loss: 1.0593 - accuracy: 0.6000 - val_loss: 0.6189 - val_accuracy: 0.6406
#
# Epoch 00115: val_loss did not improve from 0.36910
# Epoch 116/1000
# 10/10 [==============================] - 3s 299ms/step - loss: 0.8739 - accuracy: 0.6562 - val_loss: 0.3772 - val_accuracy: 0.7188
#
# Epoch 00116: val_loss did not improve from 0.36910
# Epoch 117/1000
# 10/10 [==============================] - 3s 287ms/step - loss: 0.8947 - accuracy: 0.6656 - val_loss: 0.5280 - val_accuracy: 0.7969
#
# Epoch 00117: val_loss did not improve from 0.36910
# Epoch 118/1000
# 10/10 [==============================] - 3s 305ms/step - loss: 0.9074 - accuracy: 0.6625 - val_loss: 0.7671 - val_accuracy: 0.5156
#
# Epoch 00118: val_loss did not improve from 0.36910
# Epoch 119/1000
# 10/10 [==============================] - 3s 293ms/step - loss: 1.0477 - accuracy: 0.6750 - val_loss: 0.6854 - val_accuracy: 0.6562
#
# Epoch 00119: val_loss did not improve from 0.36910
# Epoch 120/1000
# 10/10 [==============================] - 3s 313ms/step - loss: 1.0428 - accuracy: 0.6375 - val_loss: 0.5998 - val_accuracy: 0.6875
#
# Epoch 00120: val_loss did not improve from 0.36910
# Epoch 121/1000
# 10/10 [==============================] - 3s 303ms/step - loss: 0.9940 - accuracy: 0.6281 - val_loss: 0.5457 - val_accuracy: 0.6875
#
# Epoch 00121: val_loss did not improve from 0.36910
# Epoch 122/1000
# 10/10 [==============================] - 3s 318ms/step - loss: 0.9230 - accuracy: 0.6844 - val_loss: 0.4087 - val_accuracy: 0.8438
# Epoch 00122: val_loss did not improve from 0.36910
# Epoch 123/1000
# 10/10 [==============================] - 3s 311ms/step - loss: 1.0456 - accuracy: 0.6031 - val_loss: 0.7535 - val_accuracy: 0.6250
#
# Epoch 00123: val_loss did not improve from 0.36910
# Epoch 124/1000
# 10/10 [==============================] - 3s 347ms/step - loss: 0.8349 - accuracy: 0.6500 - val_loss: 0.7876 - val_accuracy: 0.7188
#
# Epoch 00124: val_loss did not improve from 0.36910
# Epoch 125/1000
# 10/10 [==============================] - 3s 339ms/step - loss: 0.8326 - accuracy: 0.6594 - val_loss: 0.4389 - val_accuracy: 0.7656
#
# Epoch 00125: val_loss did not improve from 0.36910
# Epoch 126/1000
# 10/10 [==============================] - 3s 297ms/step - loss: 0.9023 - accuracy: 0.6187 - val_loss: 0.4770 - val_accuracy: 0.7812
#
# Epoch 00126: val_loss did not improve from 0.36910
# Epoch 127/1000
# 10/10 [==============================] - 3s 312ms/step - loss: 0.9320 - accuracy: 0.6438 - val_loss: 0.4816 - val_accuracy: 0.7812
#
# Epoch 00127: val_loss did not improve from 0.36910
# Epoch 128/1000
# 10/10 [==============================] - 3s 339ms/step - loss: 0.9048 - accuracy: 0.6219 - val_loss: 0.5017 - val_accuracy: 0.6875
#
# Epoch 00128: val_loss did not improve from 0.36910
# Epoch 129/1000
# 10/10 [==============================] - 3s 313ms/step - loss: 0.8438 - accuracy: 0.6469 - val_loss: 0.6328 - val_accuracy: 0.7812
#
# Epoch 00129: val_loss did not improve from 0.36910
# Epoch 130/1000
# 10/10 [==============================] - 4s 356ms/step - loss: 0.8752 - accuracy: 0.6625 - val_loss: 0.5093 - val_accuracy: 0.7500
#
# Epoch 00130: val_loss did not improve from 0.36910
# Epoch 131/1000
# 10/10 [==============================] - 3s 321ms/step - loss: 0.9166 - accuracy: 0.6344 - val_loss: 0.3842 - val_accuracy: 0.7969
#
# Epoch 00131: val_loss did not improve from 0.36910
# Epoch 132/1000
# 10/10 [==============================] - 3s 338ms/step - loss: 0.9088 - accuracy: 0.6375 - val_loss: 0.8494 - val_accuracy: 0.7031
#
# Epoch 00132: val_loss did not improve from 0.36910
# Epoch 133/1000
# 10/10 [==============================] - 3s 310ms/step - loss: 1.0042 - accuracy: 0.6656 - val_loss: 0.4781 - val_accuracy: 0.8438
#
# Epoch 00133: val_loss did not improve from 0.36910
# Epoch 134/1000
# 10/10 [==============================] - 3s 340ms/step - loss: 0.8914 - accuracy: 0.6500 - val_loss: 0.5502 - val_accuracy: 0.7188
#
# Epoch 00134: val_loss did not improve from 0.36910
# Epoch 135/1000
# 10/10 [==============================] - 3s 314ms/step - loss: 0.8843 - accuracy: 0.6187 - val_loss: 0.4085 - val_accuracy: 0.7656
#
# Epoch 00135: val_loss did not improve from 0.36910
# Epoch 136/1000
# 10/10 [==============================] - 3s 335ms/step - loss: 0.9628 - accuracy: 0.5906 - val_loss: 0.6008 - val_accuracy: 0.6875
#
# Epoch 00136: val_loss did not improve from 0.36910
# Epoch 137/1000
# 10/10 [==============================] - 3s 309ms/step - loss: 0.8996 - accuracy: 0.6469 - val_loss: 0.5832 - val_accuracy: 0.7812
#
# Epoch 00137: val_loss did not improve from 0.36910
# Epoch 00137: early stopping

# %%
import matplotlib.pyplot as plt
# plt.plot(hist.history["acc"])
# plt.plot(hist.history['val_acc'])
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title("model loss")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.legend(["Loss","Validation Loss"])
plt.show()
plt.savefig('chart loss.png')

scores = model.evaluate(X_test, y_test, verbose=1)

print("Test loss", scores[0])
print("Test accuracy", scores[1])

print("total train : ", y_test.size)
print("true train : ", (y_test == 1).sum())
print("false train : ", (y_test == 0).sum())

print((y_test == 0).sum() / y_test.size)
print((y_test == 1).sum() / y_test.size)
# Out:
# 3023/3023 [==============================] - 9s 3ms/step
# Test loss 0.5872278512411467
# Test accuracy 0.770095944404602
# total train :  6046
# true train :  3023
# false train :  3023
# 0.5
# 0.5

# %%
import random

print(random.randint(0, 1600))

#im = X_test[1600]
im = X_test[random.randint(0, 1600)]
plt.imshow(im)
img = np.expand_dims(im, axis=0)
out= model.predict(img)
if out[0][0] > out[0][1]:
    print("plane")
else:
    print("not plane")
# Out:
# 713
# not plane

# %%
from keras.models import load_model

z=0
for e,i in enumerate(os.listdir(path)):
    if i.startswith("4"):
        z += 1
        img = cv2.imread(os.path.join(path,i))
        ss.setBaseImage(img)
        ss.switchToSelectiveSearchFast()
        ssresults = ss.process()
        imout = img.copy()
        for e,result in enumerate(ssresults):
            if e < 2000:
                x,y,w,h = result
                timage = imout[y:y+h,x:x+w]
                resized = cv2.resize(timage, (224,224), interpolation = cv2.INTER_AREA)
                img = np.expand_dims(resized, axis=0)
                out= model.predict(img)
                if out[0][0] > 0.65:
                    cv2.rectangle(imout, (x, y), (x+w, y+h), (0, 255, 0), 1, cv2.LINE_AA)
        plt.figure()
        plt.imshow(imout)

# %%
model_name = 'airplain_various_adam.h5' 
save_dir = os.getcwd()

print(os.getcwd())

if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
    
model_path = os.path.join(save_dir, model_name)
model.save(model_path)
print('Saved trained model at %s ' % model_path)
# Out:
# C:\Users\cjung\jupiterNotebook\machine2020\homeworks\ML_final_exam\RCNN-master
# Saved trained model at C:\Users\cjung\jupiterNotebook\machine2020\homeworks\ML_final_exam\RCNN-master\airplain_various_adam.h5
